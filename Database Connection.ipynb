# %%
import pandas as pd
from config import password

# %%
import sqlalchemy as sa
engine = sa.create_engine(f'postgresql://postgres:{password}@database-1.cwp515opznhz.us-west-1.rds.amazonaws.com:5432/postgres')

# %%
query = """

SELECT home_features.Id, 
    LotArea, 
    YearBuilt, 
    Heating ,
    CentralAir,
    FullBath ,
    HalfBath ,
    BedroomAbvGr ,
    TotRmsAbvGrd ,
    GarageCars , 
	YrSold ,
    SaleType ,
    SaleCondition ,
    SalePrice

FROM home_features
JOIN cost
ON home_features.Id = cost.Id

"""






df = pd.read_sql_query(query,con=engine)

# %%
df
# Out:
#         id  lotarea yearbuilt heating centralair  fullbath  halfbath  \
# 0        1     8450      2003    GasA          Y         2         1
# 1        2     9600      1976    GasA          Y         2         0
# 2        3    11250      2001    GasA          Y         2         1
# 3        4     9550      1915    GasA          Y         1         0
# 4        5    14260      2000    GasA          Y         2         1
# ...    ...      ...       ...     ...        ...       ...       ...
# 1455  1456     7917      1999    GasA          Y         2         1
# 1456  1457    13175      1978    GasA          Y         2         0
# 1457  1458     9042      1941    GasA          Y         2         0
# 1458  1459     9717      1950    GasA          Y         1         0
# 1459  1460     9937      1965    GasA          Y         1         1
#
#       bedroomabvgr  totrmsabvgrd  garagecars yrsold saletype salecondition  \
# ...
